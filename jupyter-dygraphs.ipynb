# %% [markdown]
# # Jupyter-dygraph
#
# This notebook shows examples of the use of jupyter-dygraph. For more information see: http://dygraphs.com/.

# %%
from jupyter_dygraphs import jupyter_dygraphs

# %%
help(jupyter_dygraphs.dygraphplot)
# Out:
# Help on function dygraphplot in module jupyter_dygraphs.jupyter_dygraphs:
#
# dygraphplot(*dataframe, options={'legend': 'always'})
#     Plots the given dataframe in a jupyter notebook cell.
#
#     Keyword arguments:
#         dataframe: The input data for the plot. The first column contains the x-axis data, while
#         the remaining columns contain the series data. All columns except the first one needs to
#         be parseable to numeric.
#
#         options: A dict containing the dygraph config options.

# %% [markdown]
# ## Input-Data
#
# Jupyter-dygraph uses [pandas](https://pandas.pydata.org/) data frames as input.

# %%
import pandas

# %% [markdown]
# An example data set is taken from the [dygraphs](http://dygraphs.com/) homepage. It contains two different temperatures over time.

# %%
df=pandas.read_csv('temperatures.csv')
df.head()
# Out:
#        Date  High  Low
# 0  20070101    62   39
# 1  20070102    62   44
# 2  20070103    62   42
# 3  20070104    57   45
# 4  20070105    54   44

# %% [markdown]
# ## Plotting

# %% [markdown]
# jupyter-dygraphs takes as input the data frame and an optional dict-object, which contains the configuration options for dygraph according to [its documentation](http://dygraphs.com/).

# %%
plot=jupyter_dygraphs.dygraphplot(*[df, df], options={
    'title': 'Test jupyter-dygraph plot',
    'xlabel': 'Date',
    'ylabel': 'Temperature',
    'legend': 'always'})
plot
# Out:
#     <link rel="stylesheet" href="//cdnjs.cloudflare.com/ajax/libs/dygraph/2.1.0/dygraph.min.css">
#
#         <div id="8a9aa707-6d25-43d4-923c-d47efe96728d"></div>
#         <script type="text/javascript">
#             requirejs.config({
#                 paths: {
#                     "Dygraph": ["//cdnjs.cloudflare.com/ajax/libs/dygraph/2.1.0/dygraph.min"]
#                 }
#             });
#
#             require(['Dygraph'], function(Dygraph){
#                 new Dygraph(document.getElementById("8a9aa707-6d25-43d4-923c-d47efe96728d"), "Date,High,Low\n"+"20070101,62,39\n"+"20070102,62,44\n"+"20070103,62,42\n"+"20070104,57,45\n"+"20070105,54,44\n"+"20070106,55,36\n"+"20070107,62,45\n"+"20070108,66,48\n"+"20070109,63,39\n"+"20070110,57,37\n"+"20070111,50,37\n"+"20070112,48,35\n"+"20070113,48,30\n"+"20070114,48,28\n"+"20070115,53,28\n"+"20070116,50,30\n"+"20070117,57,37\n"+"20070118,61,33\n"+"20070119,55,35\n"+"20070120,61,35\n"+"20070121,64,43\n"+"20070122,61,36\n"+"20070123,57,35\n"+"20070124,60,35\n"+"20070125,55,39\n"+"20070126,54,44\n"+"20070127,57,48\n"+"20070128,59,45\n"+"20070129,63,45\n"+"20070130,59,41\n"+"20070131,55,48\n"+"20070201,53,46\n"+"20070202,55,44\n"+"20070203,59,37\n"+"20070204,66,39\n"+"20070205,64,43\n
,73,59\n"+"20070605,68,55\n"+"20070606,70,53\n"+"20070607,75,51\n"+"20070608,70,50\n"+"20070609,75,53\n"+"20070610,75,55\n"+"20070611,75,53\n"+"20070612,79,52\n"+"20070613,90,59\n"+"20070614,89,60\n"+"20070615,86,59\n"+"20070616,72,55\n"+"20070617,79,53\n"+"20070618,79,57\n"+"20070619,73,55\n"+"20070620,71,55\n"+"20070621,77,55\n"+"20070622,79,54\n"+"20070623,77,54\n"+"20070624,77,53\n"+"20070625,82,53\n"+"20070626,71,54\n"+"20070627,73,55\n"+"20070628,73,57\n"+"20070629,77,60\n"+"20070630,75,54\n"+"20070701,78,54\n"+"20070702,82,57\n"+"20070703,72,57\n"+"20070704,84,59\n"+"20070705,84,61\n"+"20070706,75,60\n"+"20070707,73,55\n"+"20070708,78,55\n"+"20070709,73,57\n"+"20070710,73,59\n"+"20070711,78,62\n"+"20070712,75,59\n"+"20070713,79,60\n"+"20070714,73,60\n"+"20070715,78,62\n"+"20070716,75,59\n"+"20070717,77,60\n"+"20070718,75,63\n"+"20070719,80,59\n"+"20070720,79,59\n"+"20070721,77,61\n"+"20070722,75,63\n"+"20070723,79,64\n"+"20070724,73, ...
#             })
#         </script>
#
#         <div id="0043ac7c-0464-4e64-ab18-8aafa7a8b0b9"></div>
#         <script type="text/javascript">
#             requirejs.config({
#                 paths: {
#                     "Dygraph": ["//cdnjs.cloudflare.com/ajax/libs/dygraph/2.1.0/dygraph.min"]
#                 }
#             });
#
#             require(['Dygraph'], function(Dygraph){
#                 new Dyg

# %% [markdown]
# ## Errors
#
# dygraph expects data in numeric format (except the first column). jupyter-dygraphs checks for numeric data types and complains, if a column can not be cast to a numeric value. **Please note:** A string column can still contain data which is parseable as number and thus would not raise an exception.

# %% [markdown]
# This will work:

# %%
df_wrong=pandas.read_csv('temperatures.csv')
df_wrong['test']=df_wrong.apply(lambda row: str(row['High']*2), axis=1)
plot=jupyter_dygraphs.dygraphplot(df_wrong, {
    'title': 'Test jupyter-dygraph plot',
    'xlabel': 'Date',
    'ylabel': 'Temperature',
    'legend': 'always'})
plot
# Out:
#     <link rel="stylesheet" href="//cdnjs.cloudflare.com/ajax/libs/dygraph/2.1.0/dygraph.min.css">
#     <div id="b846069d-1045-4bf3-9fca-0af87a89e4d9"></div>
#     <script type="text/javascript">
#         requirejs.config({
#             paths: {
#                 "Dygraph": ["//cdnjs.cloudflare.com/ajax/libs/dygraph/2.1.0/dygraph.min"]
#             }
#         });
#
#         require(['Dygraph'], function(Dygraph){
,122\n"+"20070419,57,42,114\n"+"20070420,64,46,128\n"+"20070421,61,43,122\n"+"20070422,63,48,126\n"+"20070423,70,44,140\n"+"20070424,66,46,132\n"+"20070425,66,48,132\n"+"20070426,69,48,138\n"+"20070427,82,50,164\n"+"20070428,81,55,162\n"+"20070429,70,53,140\n"+"20070430,77,51,154\n"+"20070501,70,48,140\n"+"20070502,66,52,132\n"+"20070503,63,48,126\n"+"20070504,64,51,128\n"+"20070505,73,46,146\n"+"20070506,88,54,176\n"+"20070507,91,57,182\n"+"20070508,84,60,168\n"+"20070509,73,55,146\n"+"20070510,57,52,114\n"+"20070511,64,51,128\n"+"20070512,64,50,128\n"+"20070513,72,46,144\n"+"20070514,66,50,132\n"+"20070515,63,51,126\n"+"20070516,70,48,140\n"+"20070517,68,50,136\n"+"20070518,73,50,146\n"+"20070519,70,52,140\n"+"20070520,73,51,146\n"+"20070521,78,54,156\n"+"20070522,81,51,162\n"+"20070523,86,55,172\n"+"20070524,78,55,156\n"+"20070525,69,54,138\n"+"20070526,69,55,138\n"+"20070527,69,54,138\n"+"20070528,73,52,146\n"+"20070529,69,53,138\n"+"20070530,66,55,132\n"+"20070531,64,54,128\n"+"20070601,66,54,132\n"+"20070602,64,54,128\n"+"20070603,70,55,140\n"+"20070604,73,59,146\n"+"20070605,68,55,136\n"+"20070606,70,53,140\n"+"20070607,75,51,150\n"+"20070608,70,50,140\n"+"20070609,75,53,150\n"+"20070610,75,55,150\n"+"20070611,75,53,150\n"+"20070612,79,52,158\n"+"20070613,90,59,180\n"+"20070614,89,60,178\n"+"20070615,86,59,172\n"+"20070616,72,55,144\n"+"20070617,79,53,158\n"+"20070618,79,57,158\n"+"200 ...

# %% [markdown]
# This will not work:

# %%
df_wrong=pandas.read_csv('temperatures.csv')
df_wrong['test']=df_wrong.apply(lambda row: "{"+str(row['High']*2)+"}", axis=1)
plot=jupyter_dygraphs.dygraphplot(df_wrong, {
    'title': 'Test jupyter-dygraph plot',
    'xlabel': 'Date',
    'ylabel': 'Temperature',
    'legend': 'always'})
plot
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "{124}"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/jupyter-dygraphs/jupyter_dygraphs.py in dygraphplot(dataframe, options)
#      25         try:
# ---> 26             pandas.to_numeric(dataframe[col])
#      27         except:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     132             values = lib.maybe_convert_numeric(values, set(),
# --> 133                                                coerce_numeric=coerce_numeric)
#     134
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "{124}" at position 0
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-7-fc190c8f8be7> in <module>()
#       5     'xlabel': 'Date',
#       6     'ylabel': 'Temperature',
# ----> 7     'legend': 'always'})
#       8 plot
#
# ~/jupyter-dygraphs/jupyter_dygraphs.py in dygraphplot(dataframe, options)
#      26             pandas.to_numeric(dataframe[col])
#      27         except:
# ---> 28             raise Exception("Dataframe contains non-numeric column: {}".format(col))
#      29     html = """
#      30     <link rel="stylesheet" href="//cdnjs.cloudflare.com/ajax/libs/dygraph/2.1.0/dygraph.min.css">
#
# Exception: Dataframe contains non-numeric column: test
